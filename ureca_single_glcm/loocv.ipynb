# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from random_forest import RandomForestLOOCV

# %%
dec = pd.read_csv("data/glcm_merged_windowed/dec_merged_glcm_windowed.csv")
may = pd.read_csv("data/glcm_merged_windowed/may_merged_glcm_windowed.csv")
all_glcm_merged_window = pd.concat([dec, may], axis=0, ignore_index=True)
display(all_glcm_merged_window)
# Out:
#     index_               tree_name  r_glcm_mean  r_mean_homogeneity  \
# 0        0    Falcataria Moluccana   107.381083            0.238465
# 1        1         Ficus Variegata    95.544812            0.101588
# 2        2            Bridelia Sp.    89.763883            0.152445
# 3        3    Falcataria Moluccana   106.732557            0.228239
# 4        4    Falcataria Moluccana   113.607040            0.267440
# ..     ...                     ...          ...                 ...
# 62      29             Leea Indica   117.308075            0.178281
# 63      30   Dillenia Suffruticosa    82.334574            0.104853
# 64      31    Sterculia Parviflora    93.068316            0.109899
# 65      32         Ficus Variegata   104.969986            0.100134
# 66      33  Spathodea Campanulatum    99.522569            0.087551
#
#     r_mean_contrast  r_mean_dissimilarity  r_mean_ASM  r_mean_correlation  \
# 0         72.016964              5.293932    0.000711            0.931976
# ...

# %%
display(all_glcm_merged_window)
# Out:
#     index_               tree_name  r_glcm_mean  r_mean_homogeneity  \
# 0        0    Falcataria Moluccana   107.381083            0.238465
# 1        1         Ficus Variegata    95.544812            0.101588
# 2        2            Bridelia Sp.    89.763883            0.152445
# 3        3    Falcataria Moluccana   106.732557            0.228239
# 4        4    Falcataria Moluccana   113.607040            0.267440
# ..     ...                     ...          ...                 ...
# 62      29             Leea Indica   117.308075            0.178281
# 63      30   Dillenia Suffruticosa    82.334574            0.104853
# 64      31    Sterculia Parviflora    93.068316            0.109899
# 65      32         Ficus Variegata   104.969986            0.100134
# 66      33  Spathodea Campanulatum    99.522569            0.087551
#
#     r_mean_contrast  r_mean_dissimilarity  r_mean_ASM  r_mean_correlation  \
# 0         72.016964              5.293932    0.000711            0.931976
# ...

# %%
all_glcm_merged_window.to_csv("data/glcm_merged_windowed/all_glcm_merged_window.csv")

# %%
df = pd.read_csv("accuracy_and_features.csv")
top = df.sort_values("balanced_accuracy")
top = top.head(16)["feature"].tolist()
columns_to_use = ["tree_name"]
columns_to_use.extend(top)
data_to_use = all_glcm_merged_window[columns_to_use]

# %%
display(data_to_use)
# Out:
#                  tree_name  RedEdge_HOMOGENEITY_75th  r_mean_contrast  \
# 0     Falcataria Moluccana                  0.089539        72.016964
# 1          Ficus Variegata                  0.067505       369.911821
# 2             Bridelia Sp.                  0.114014       150.408908
# 3     Falcataria Moluccana                  0.074768        94.193548
# 4     Falcataria Moluccana                  0.083313        54.574110
# ..                     ...                       ...              ...
# 62             Leea Indica                  0.080200       122.956314
# 63   Dillenia Suffruticosa                  0.064728       258.725051
# 64    Sterculia Parviflora                  0.104431       181.985333
# 65         Ficus Variegata                  0.062317       348.465817
# 66  Spathodea Campanulatum                  0.076782       484.560930
#
#     Green_HOMOGENEITY_median  r_mean_dissimilarity  RedEdge_MEAN_I_mean  \
# ...

# %%
rf_loocv = RandomForestLOOCV(data_to_use)

# %%
rf_loocv.execute_LOOCV()
# Out:
# /Users/nicoleyap/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sx/8nz4dts119bfc1svlcbykndr0000gn/T/ipykernel_62196/927720187.py in <module>
# ----> 1 rf_loocv.execute_LOOCV()
#
# ~/PycharmProjects/ureca_single_glcm/random_forest.py in execute_LOOCV(self)
#     213                                                    max_depth=6)
#     214             rf_model.fit(X_train, y_train)
# --> 215             y_pred = rf_model.predict(X_test)
#     216
#     217             if (y_pred == y_test):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     806             The predicted classes.
#     807         """
# ...
